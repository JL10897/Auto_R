# %%
import pickle
import numpy as np
import time,sys,glob,os
import pandas as pd
import scipy.ndimage as ndi
import cc3d
import cv2
import open3d as o3d

from skimage import color, morphology, measure
from skimage.transform import downscale_local_mean
from skimage.registration import phase_cross_correlation

from scipy.stats import zscore
from scipy import sparse

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from functions.cellregister import *
from functions.iterive_non_rigid import *
# from functions.tiling import *
import functions.tiling as tiling  # 如果tiling.py在同一个functions目录下

# %load_ext autoreload
# %autoreload 2
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def load_and_extract_matches(lut_path):
    """Load LUT and extract matched coordinates and images"""
    with open(lut_path, 'rb') as f:
        lookup_table = pickle.load(f)
    
    # Get images
    invivo_image = lookup_table['in_vivo']['Transformed']
    exvivo_image = lookup_table['exvivo_GCAMP']['Transformed']
    
    # Extract matched coordinates
    in_vivo_coords = []
    ex_vivo_coords = []
    
    for ex_cell in lookup_table['exvivo_GCAMP']['cells']:
        if 'in_vivo_id' in ex_cell:
            # Find matching in vivo cell
            in_vivo_cell = next(cell for cell in lookup_table['in_vivo']['cells'] 
                               if cell['id'] == ex_cell['in_vivo_id'])
            in_vivo_coords.append(in_vivo_cell['coordinates'])
            ex_vivo_coords.append(ex_cell['coordinates'])
    
    return (np.array(in_vivo_coords), np.array(ex_vivo_coords), 
            invivo_image, exvivo_image)

# %%
lut_path = "/scratch/jl10897/Automatic_Registration/LUT_multimodal_487_Region2.pkl"
in_vivo_coord = load_and_extract_matches(lut_path)[0]
ex_vivo_coord = load_and_extract_matches(lut_path)[1]
invivo_image = load_and_extract_matches(lut_path)[2]
exvivo_image = load_and_extract_matches(lut_path)[3]

# %%
# 已经给了source points 和 target points，所以直接算rigid transform
def compute_rigid_transform(source_points, target_points):
    """Compute rigid transformation (rotation, translation, scale)"""
    # Center the point sets
    source_centroid = np.mean(source_points, axis=0)
    target_centroid = np.mean(target_points, axis=0)
    
    centered_source = source_points - source_centroid
    centered_target = target_points - target_centroid
    
    # Compute optimal rotation
    H = centered_source.T @ centered_target
    U, _, Vt = np.linalg.svd(H)
    R = Vt.T @ U.T
    
    # Ensure right-handed coordinate system
    if np.linalg.det(R) < 0:
        Vt[-1,:] *= -1
        R = Vt.T @ U.T
    
    # Compute scale
    scale = np.sum(centered_target * (R @ centered_source.T).T) / np.sum(centered_source * centered_source)
    
    # Compute translation
    t = target_centroid - scale * (R @ source_centroid)
    
#     t 就是shift
#     scale 
    return R, t, scale

# %%
def visualize_registration_step(original, transformed, target, step_name):
    """Visualize registration results with proper colormaps"""
    plt.figure(figsize=(15, 5))
    
    plt.subplot(131)
    plt.imshow(np.max(original, axis=0), cmap='Greens')  # Changed from 'green' to 'Greens'
    plt.title('Original In Vivo')
    plt.axis('off')
    
    plt.subplot(132)
    plt.imshow(np.max(target, axis=0), cmap='Reds', alpha=0.5)  # Changed from 'red' to 'Reds'
    plt.imshow(np.max(transformed, axis=0), cmap='Greens', alpha=0.5)  # Changed from 'green' to 'Greens'
    plt.title(f'Overlay After {step_name}')
    plt.axis('off')
    
    plt.subplot(133)
    plt.imshow(np.max(target, axis=0), cmap='Reds')  # Changed from 'red' to 'Reds'
    plt.title('Target Ex Vivo')
    plt.axis('off')
    
    plt.tight_layout()
    plt.show()

def visualize_3D_points(in_vivo_coords, ex_vivo_coords, transformed_coords=None):
    """Visualize 3D point correspondences"""
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot original in vivo points
    ax.scatter(in_vivo_coords[:, 0], in_vivo_coords[:, 1], in_vivo_coords[:, 2], 
              c='green', marker='o', label='In Vivo')
    
    # Plot ex vivo points
    ax.scatter(ex_vivo_coords[:, 0], ex_vivo_coords[:, 1], ex_vivo_coords[:, 2], 
              c='red', marker='^', label='Ex Vivo')
    
    # Plot transformed points if provided
    if transformed_coords is not None:
        ax.scatter(transformed_coords[:, 0], transformed_coords[:, 1], transformed_coords[:, 2],
                  c='blue', marker='s', label='Transformed In Vivo')
    
    # Draw lines between corresponding points
    for i in range(len(in_vivo_coords)):
        if transformed_coords is not None:
            points = np.array([in_vivo_coords[i], transformed_coords[i], ex_vivo_coords[i]])
        else:
            points = np.array([in_vivo_coords[i], ex_vivo_coords[i]])
        ax.plot(points[:, 0], points[:, 1], points[:, 2], 'k-', alpha=0.2)
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    plt.title('3D Point Correspondences')
    plt.show()

# %%
lut_path = "/scratch/jl10897/Automatic_Registration/LUT_multimodal_487_Region2.pkl"

"""Main function with enhanced visualizations"""
# 1. Load data and extract matches
in_vivo_coords, ex_vivo_coords, invivo_image, exvivo_image = load_and_extract_matches(lut_path)
print(f"Number of matched pairs: {len(in_vivo_coords)}")

# Visualize initial point correspondences
print("\nInitial point correspondences:")
visualize_3D_points(in_vivo_coords, ex_vivo_coords)

# # 2. Compute and apply rigid transformation
# R, t, scale = compute_rigid_transform(in_vivo_coords, ex_vivo_coords)
# total_R = R
# total_shift = t
# total_scale = scale
# print("\nRigid Transform Parameters:")
# print(f"Rotation:\n{R}")
# print(f"Translation(shift): {t}")
# print(f"Scale: {scale}")
# Out:
# Number of matched pairs: 37
#
# Initial point correspondences:

# %%
bhat = wahba(in_vivo_coords, ex_vivo_coords)  # transforms from source to target

# %%
print(bhat)
# Out:
# [[ 9.99367347e-01 -7.33511186e-03 -3.48008945e-02]
#  [ 1.23367187e-02  9.89242503e-01  1.45763766e-01]
#  [ 3.33573305e-02 -1.46100877e-01  9.88707147e-01]
#  [-6.44701533e+01 -8.20183094e+02 -1.83036724e+03]]

# %%
# print(f'euler (radiant):\n{rotationMatrixToEulerAngles(total_R/total_scale)}')
# print(f'euler (degree):\n{angles(rotationMatrixToEulerAngles(total_R/total_scale))}')



# # Transform points and visualize
# transformed_coords = scale * (R @ in_vivo_coords.T).T + t
# print("\nAfter rigid transformation:")
# visualize_3D_points(in_vivo_coords, ex_vivo_coords, transformed_coords)

# Transform image
# rigid_transformed = apply_rigid_transform(invivo_image, exvivo_image, R, t, scale)



rigid_transformed = apply_total_R(invivo_image,exvivo_image, total_R, total_shift)

# %%
scl_1 =0.1
scl_2 =0.2
plt.figure(figsize = (23,11))
plt.subplot(1,2,1)
plt.imshow(gray2RGB(exvivo_image, col='r',scl = scl_1) )
plt.subplot(1,2,2)
plt.imshow(gray2RGB(exvivo_image, col='r',scl = scl_1) + 
           gray2RGB(rigid_transformed, col = 'g', scl = scl_2))
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(gray2RGB(invivo_image, col = 'g', scl = scl_2))
plt.yticks([])
plt.tight_layout()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..10.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00888282083966534..10.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..5.0].
# /tmp/ipykernel_1193072/3900464310.py:13: UserWarning: tight_layout not applied: number of columns in subplot specifications must be multiples of one another.
#   plt.tight_layout()

# %%
# # 3. Apply non-rigid transformation
# final_image, _, ncc_list, _ = learn_and_apply_deformable(rigid_transformed, exvivo_image, vec_ds=3)
# Out:
# iteration 0...
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 116534032.83264744 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 140162127.94650212 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 147501805.75171465 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 152100138.6776406 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150903523.76817554 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149113546.8806585 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149760409.67352536 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151466676.2578875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 140339284.8998627 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130557082.6392318 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130230546.91083671 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130078564.18381348 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130191558.02057616 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130121717.92866942 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 129709803.01508918 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128189473.7174211 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127777173.75994506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127999299.2798354 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128138244.97393695 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128210556.569273 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128277684.60905354 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128673201.06310013 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 129113165.06447186 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 129361582.17009605 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 129044472.38545959 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128730747.78600827 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128688949.52949247 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 128471003.5665295 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127621987.83676268 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 126619254.20576134 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 126673230.20576136 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 126904866.91358025 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127021808.88477372 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127087335.06447192 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127038329.12620026 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127272176.67901237 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127747979.40054874 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127694666.13580246 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127396011.68724282 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127496060.12208503 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127614880.9300411 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 127470143.43758579 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 56819509.22908094 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149376880.46776408 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 175566888.51303157 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 176268962.3155007 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 175627656.78737995 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 173074756.2098765 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 170775718.65706453 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 170808643.81069964 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 172656459.52812067 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 170889870.19890258 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 159086580.06310016 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 152219032.9794238 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150020334.89437586 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149986114.58573392 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150030042.19204375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149616444.9355282 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149624813.55144033 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149932052.32647464 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150001548.680384 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150179204.7325102 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150312674.61179698 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150281871.99999997 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150618641.7037037 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150832325.4801097 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151076416.04389578 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150950774.5829904 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150554517.1646091 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150523437.13168722 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150189401.58573386 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149570554.4663924 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149492435.6748972 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149555680.90260637 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149880742.63237306 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149937160.7091907 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150241344.12345675 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150190382.80932775 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150321117.13854602 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150554059.0946503 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150355225.49519888 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150031589.40192044 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150018743.7146776 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150361050.2592592 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150445562.43621403 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 67170267.09465022 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150343848.5816187 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 175939553.3333333 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 176738400.08504802 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 175557763.48559666 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 172003295.99451303 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 169921874.52126205 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 170905806.41289443 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 171779818.31961593 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 172705242.48010972 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 171024029.38683125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 167797246.77914947 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 155878256.5706447 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149945101.47873804 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149972909.6076819 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151572471.33058986 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150582902.74897122 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150404638.99725652 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150834265.94238687 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151212389.71604937 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 152256569.81344303 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150491512.11522636 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151131050.98491082 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151483153.50068584 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150866037.65294933 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150546728.18792874 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150608287.12620023 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150429699.28669396 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150162129.18930045 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149643273.0260631 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149550253.29080927 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149498459.6337448 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149779965.68724272 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149871908.09602195 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149864135.97256514 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150167171.88751712 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150445258.52949247 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150633813.24279833 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150561042.7517147 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150217260.43347052 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150059232.4430726 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150116480.62825796 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150380038.23868313 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 67298918.91083673 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150156120.340192 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 176050438.97942382 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 176077823.55281195 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 174061881.90260637 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 172106319.05761316 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 173565052.3827161 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 173727451.63374478 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 169256387.75857347 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 173809351.51165986 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 168612132.0274347 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 167158598.97256517 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 161715516.35253775 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 156308303.27572018 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 155116978.67489704 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 159472250.43758577 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 156172488.50754458 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150293833.0713307 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150358127.3017833 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150750004.8573388 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151303844.09602192 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150297067.84636492 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150765180.70644718 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 151104814.14540467 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# ...
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 158604231.26611796 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150182829.3840877 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149967319.32510287 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 150073286.73525375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149912699.68998632 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 149883392.7956104 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 66953160.245541856 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 92184387.6639232 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106704639.09739363 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106828678.79698217 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106939118.79698215 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107203637.5925926 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107089800.946502 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107315453.11934151 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107516051.15500684 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107716386.61591221 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107850333.75171468 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 108192804.89849107 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107690621.56104258 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107711055.2043896 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107476087.10562411 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106881000.68724276 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106722715.28257886 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106787063.46227711 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106716661.0823045 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106745308.64883398 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107134733.55418372 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107357065.69958839 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107506093.55144033 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107818098.63511662 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107995906.17695469 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107725980.22908089 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107977569.60082299 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107729672.98628259 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107539037.19204393 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 106694254.2853224 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 108760502.69821675 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 115974168.03978054 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 122533625.75308645 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 130462124.38683137 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 134176186.04526755 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 137125732.17695472 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 137115884.82853222 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 112329178.3429355 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107245838.10150893 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107117458.22222228 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107227798.84499308 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107125265.37997256 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 107046521.4663923 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 47851937.44718792 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# iteration 5...
# iteration 10...
# iteration 15...
# iteration 20...
# iteration 25...

# %%
# 3. Apply non-rigid transformation
downsampled_image, final_image, ncc_list, vector_fields = learn_and_apply_deformable(rigid_transformed, exvivo_image, vec_ds=3)

# %%
scl_1 =0.1
scl_2 =0.2
plt.figure(figsize = (23,11))
plt.subplot(1,3,1)
plt.imshow(gray2RGB(exvivo_image, col='r',scl = scl_1) )
plt.subplot(1,3,2)
plt.imshow(gray2RGB(exvivo_image, col='r',scl = scl_1) + 
           gray2RGB(final_image, col = 'g', scl = scl_2))
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(gray2RGB(invivo_image, col = 'g', scl = scl_2))
plt.yticks([])
plt.tight_layout()

# %%
visualize_registration_step(rigid_transformed, final_image, exvivo_image, "Non-rigid Registration")

plot_registration_progress(ncc_list)
