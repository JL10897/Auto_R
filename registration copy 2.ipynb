# %%
import pickle
import numpy as np
import time,sys,glob,os
import pandas as pd
import scipy.ndimage as ndi
import cc3d
import cv2
import open3d as o3d

from skimage import color, morphology, measure
from skimage.transform import downscale_local_mean
from skimage.registration import phase_cross_correlation

from scipy.stats import zscore
from scipy import sparse

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from functions.cellregister import *
from functions.iterive_non_rigid import *
# from functions.tiling import *
import functions.tiling as tiling  # 如果tiling.py在同一个functions目录下

# %load_ext autoreload
# %autoreload 2
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
pip install ipykernel

# %%
conda activate your_environment_name

# %% [markdown]
# ### 参数

# %%
add_edge = np.array((10,100,100))
outputshape = add_edge*2

max_iteration = 100  # shape ICP max iteration 
thre = 8 # shape ICP parametrs
ds_sz = 5 # shape ICP downsample size
with_scaling = True # shape ICP learn the scaling 
ds_sz_aff=3 # NCC downsample size
vec_ds = 3 # vector field downsample size. 
max_correspondence_distance = 50

# %% [markdown]
# ### 加载

# %%
def load_and_extract_matches(lut_path):
    """Load LUT and extract matched coordinates and images"""
    with open(lut_path, 'rb') as f:
        lookup_table = pickle.load(f)
    
    # Get images
    invivo_image = lookup_table['in_vivo']['Transformed']
    exvivo_image = lookup_table['exvivo_GCAMP']['Transformed']
    
    # Extract matched coordinates
    in_vivo_coords = []
    ex_vivo_coords = []
    
    for ex_cell in lookup_table['exvivo_GCAMP']['cells']:
        if 'in_vivo_id' in ex_cell:
            # Find matching in vivo cell
            in_vivo_cell = next(cell for cell in lookup_table['in_vivo']['cells'] 
                               if cell['id'] == ex_cell['in_vivo_id'])
            in_vivo_coords.append(in_vivo_cell['coordinates'])
            ex_vivo_coords.append(ex_cell['coordinates'])
    
    return (np.array(in_vivo_coords), np.array(ex_vivo_coords), 
            invivo_image, exvivo_image)

# %%
lut_path = "/scratch/jl10897/Automatic_Registration/LUT_multimodal_487_Region2.pkl"
in_vivo_coord = load_and_extract_matches(lut_path)[0]
ex_vivo_coord = load_and_extract_matches(lut_path)[1]
invivo_image = load_and_extract_matches(lut_path)[2]
exvivo_image = load_and_extract_matches(lut_path)[3]

# %% [markdown]
# ### 查看coordinates

# %%
# Check coordinate order
print("First few in_vivo coordinates:")
print(in_vivo_coords[:3])
print("\nFirst few ex_vivo coordinates:")
print(ex_vivo_coords[:3])

# Print axis ranges
print("\nIn Ranges:")
print("in_vivo z:", in_vivo_coords[:,0].min(), "-", in_vivo_coords[:,0].max())
print("in_vivo x:", in_vivo_coords[:,1].min(), "-", in_vivo_coords[:,1].max()) 
print("in_vivo y:", in_vivo_coords[:,2].min(), "-", in_vivo_coords[:,2].max())

print("\nEx Ranges:")
print("ex_vivo z:", ex_vivo_coords[:,0].min(), "-", ex_vivo_coords[:,0].max())
print("ex_vivo x:", ex_vivo_coords[:,1].min(), "-", ex_vivo_coords[:,1].max()) 
print("ex_vivo y:", ex_vivo_coords[:,2].min(), "-", ex_vivo_coords[:,2].max())
# Out:
# First few in_vivo coordinates:
# [[ 10.         222.03079473  51.28710104]
#  [ 10.         264.07720707  52.93597996]
#  [ 10.         271.90938192  76.84472423]]
#
# First few ex_vivo coordinates:
# [[   0.         1091.1953964  1234.3254837 ]
#  [   0.         1264.10414196 1210.08593993]
#  [   0.         1286.93875721 1315.5115125 ]]
#
# In Ranges:
# in_vivo z: 9.0 - 21.0
# in_vivo x: 142.1661348825179 - 396.09293707718075
# in_vivo y: 51.28710104243543 - 399.4058442561061
#
# Ex Ranges:
# ex_vivo z: 0.0 - 1.0
# ex_vivo x: 835.2207981932627 - 1883.0714799233083
# ex_vivo y: 1210.085939926042 - 2524.552165582886

# %% [markdown]
# 缩放

# %%
from scipy.ndimage import zoom

# 计算缩放因子
scale_factors = [
    (ex_vivo_coords[:, i].max() - ex_vivo_coords[:, i].min()) /
    (in_vivo_coords[:, i].max() - in_vivo_coords[:, i].min())
    for i in range(3)
]

# 打印缩放因子以检查
print("Scale factors (z, x, y):", scale_factors)

# 对 in-vivo 坐标进行缩放
scaled_in_vivo_coords = in_vivo_coords.copy()
for i in range(3):
    scaled_in_vivo_coords[:, i] *= scale_factors[i]

# 对图像进行缩放
scaled_invivo_image = zoom(invivo_image, scale_factors, order=3)  # order=3 表示三次插值
print("Scaled in-vivo image shape:", scaled_invivo_image.shape)

# 打印缩放后的范围
print("\nScaled in-vivo coordinates:")
print(f"z: {scaled_in_vivo_coords[:,0].min()} - {scaled_in_vivo_coords[:,0].max()}")
print(f"x: {scaled_in_vivo_coords[:,1].min()} - {scaled_in_vivo_coords[:,1].max()}")
print(f"y: {scaled_in_vivo_coords[:,2].min()} - {scaled_in_vivo_coords[:,2].max()}")
# Out:
# Scale factors (z, x, y): [0.08333333333333333, 4.126585585584434, 3.775913395303861]
#
# Scaled in-vivo coordinates:
# z: 0.75 - 1.75
# x: 586.6607229644507 - 1634.5114046944962
# y: 193.65565183243456 - 1508.1218774892786

# %% [markdown]
# 平移

# %%
# # 计算平移因子，使得范围中心对齐
# translation_factors = [
#     (ex_vivo_coords[:, i].min() + ex_vivo_coords[:, i].max()) / 2 -
#     (scaled_in_vivo_coords[:, i].min() + scaled_in_vivo_coords[:, i].max()) / 2
#     for i in range(3)
# ]

# # 对 scaled_in_vivo_coords 应用平移
# aligned_in_vivo_coords = scaled_in_vivo_coords.copy()
# for i in range(3):
#     aligned_in_vivo_coords[:, i] += translation_factors[i]

# # 打印平移后的范围
# print("\nAligned in-vivo ranges:")
# print(f"z: {aligned_in_vivo_coords[:, 0].min()} - {aligned_in_vivo_coords[:, 0].max()}")
# print(f"x: {aligned_in_vivo_coords[:, 1].min()} - {aligned_in_vivo_coords[:, 1].max()}")
# print(f"y: {aligned_in_vivo_coords[:, 2].min()} - {aligned_in_vivo_coords[:, 2].max()}")
# Out:
# Aligned in-vivo ranges:
# z: 0.0 - 1.0
# x: 835.2207981932626 - 1883.071479923308
# y: 1210.085939926042 - 2524.552165582886

# %% [markdown]
# 可视化

# %%
def visualize_3D_points(in_vivo_coords, ex_vivo_coords, transformed_coords=None):
    """Visualize 3D point correspondences"""
    fig = plt.figure(figsize=(10, 10))
    ax = fig.add_subplot(111, projection='3d')
    
    # Plot original in vivo points
    ax.scatter(in_vivo_coords[:, 0], in_vivo_coords[:, 1], in_vivo_coords[:, 2], 
              c='green', marker='o', label='In Vivo')
    
    # Plot ex vivo points
    ax.scatter(ex_vivo_coords[:, 0], ex_vivo_coords[:, 1], ex_vivo_coords[:, 2], 
              c='red', marker='^', label='Ex Vivo')
    
    # Plot transformed points if provided
    if transformed_coords is not None:
        ax.scatter(transformed_coords[:, 0], transformed_coords[:, 1], transformed_coords[:, 2],
                  c='blue', marker='s', label='Transformed In Vivo')
    
    # Draw lines between corresponding points
    for i in range(len(in_vivo_coords)):
        if transformed_coords is not None:
            points = np.array([in_vivo_coords[i], transformed_coords[i], ex_vivo_coords[i]])
        else:
            points = np.array([in_vivo_coords[i], ex_vivo_coords[i]])
        ax.plot(points[:, 0], points[:, 1], points[:, 2], 'k-', alpha=0.2)
    
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.legend()
    plt.title('3D Point Correspondences')
    plt.show()

# %%
"""Main function with enhanced visualizations"""
print(f"Number of matched pairs: {len(in_vivo_coords)}")
print("\nInitial point correspondences:")
visualize_3D_points(in_vivo_coords, ex_vivo_coords)
# Out:
# Number of matched pairs: 37
#
# Initial point correspondences:

# %%
visualize_3D_points(in_vivo_coords, ex_vivo_coords, transformed_coords=scaled_in_vivo_coords)

# %%
# 没有scal
# bhat = wahba(in_vivo_coords, ex_vivo_coords)  # transforms from source to target
# scale 之后
bhat = wahba(aligned_in_vivo_coords, ex_vivo_coords)

# %%
print(bhat)
# Out:
# [[ 9.99999986e-01  4.86583829e-05 -1.62775914e-04]
#  [-6.98769546e-05  9.91114615e-01 -1.33010583e-01]
#  [ 1.54857507e-04  1.33010592e-01  9.91114604e-01]
#  [-2.56012492e-01 -2.25929646e+02  2.09178538e+02]]

# %%
# 没有scale
# tran, im1_wahba = run_doubleICP(invivo_image, exvivo_image, bhat, in_vivo_coords, ex_vivo_coords, max_correspondence_distance = 100)
# scale 之后
tran, im1_wahba = run_doubleICP(invivo_image, exvivo_image, bhat, aligned_in_vivo_coords, ex_vivo_coords, max_correspondence_distance = 100)

# %%
# ICP debug
print("ICP Transformation:")
print("Rotation part:\n", tran[:3,:3])
print("Translation part:\n", tran[:3,3])
print("Scale:", np.cbrt(np.linalg.det(tran[:3,:3])))
# Out:
# ICP Transformation:
# Rotation part:
#  [[ 1.04767274  0.01334618 -0.0095406 ]
#  [-0.01305069  1.04723606  0.03183752]
#  [ 0.00994098 -0.03171478  1.04727392]]
# Translation part:
#  [  -0.99193947 -124.88106273  -25.88434644]
# Scale: 1.0478011822483435

# %%
# ICP Debug

# def visualize_point_matches(source_points, target_points):
#     fig = plt.figure(figsize=(10,10))
#     ax = fig.add_subplot(111, projection='3d')
#     ax.scatter(source_points[:,0], source_points[:,1], source_points[:,2], c='r', label='source')
#     ax.scatter(target_points[:,0], target_points[:,1], target_points[:,2], c='b', label='target')
#     plt.legend()
#     plt.show()

def visualize_point_matches(source_points, target_points):
    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(111, projection='3d')
    
    # 设定固定的轴范围
    x_min, x_max = min(source_points[:,0].min(), target_points[:,0].min()), max(source_points[:,0].max(), target_points[:,0].max())
    y_min, y_max = min(source_points[:,1].min(), target_points[:,1].min()), max(source_points[:,1].max(), target_points[:,1].max())
    z_min, z_max = min(source_points[:,2].min(), target_points[:,2].min()), max(source_points[:,2].max(), target_points[:,2].max())
    
    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_zlim(z_min, z_max)
    
    ax.scatter(source_points[:,0], source_points[:,1], source_points[:,2], c='r', label='source')
    ax.scatter(target_points[:,0], target_points[:,1], target_points[:,2], c='b', label='target')
    plt.legend()
    plt.show()

# 查看原始匹配点
visualize_point_matches(in_vivo_coords, ex_vivo_coords)

# 查看变换后的点
transformed_points = np.c_[in_vivo_coords, np.ones((in_vivo_coords.shape[0],1))] @ bhat
visualize_point_matches(transformed_points, ex_vivo_coords)

# %%
total_R, total_shift, total_scale = get_final_transformation(tran,bhat)

# %%
# print out the final results. 
print('rotation matrix:\n',total_R)
print(f'scale:\n{total_scale}')
print('shift:\n',total_shift)
# print(f'euler (radiant):\n{rotationMatrixToEulerAngles(total_R/total_scale)}')
# print(f'euler (degree):\n{angles(rotationMatrixToEulerAngles(total_R/total_scale))}')
# Out:
# rotation matrix:
#  [[ 1.04685633e+00  9.39038758e-04  4.44776964e-02]
#  [ 6.91170119e-03  1.03141466e+00 -1.84454168e-01]
#  [-4.39474192e-02  1.84581228e-01  1.03047839e+00]]
# scale:
# 1.0478011822483428
# shift:
#  [  -8.27200763 1058.97978063 1711.85083778]

# %%
# 如果是二值图像 (segmentation)
# invivo_binary_transformed = apply_doubleICP_2_binary(invivo_seg, exvivo_seg, total_R, total_shift)

# 如果是原始图像
# invivo_transformed = apply_total_R(invivo_image, exvivo_image, total_R, total_shift)
im1_happy= apply_total_R(invivo_image, exvivo_image, bhat[:3,:3], bhat[-1])

# %%
img_de,z_de,ncc_list,vec_field_smooth_list = learn_and_apply_deformable(im1_happy,exvivo_image,vec_ds=2)
# img_de, z_de, ncc_list, vec_field_smooth_list = learn_and_apply_deformable(im1_wahba, exvivo_image, vec_ds)
# Out:
# iteration 0...
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 418140770.2500001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 508316139.56249994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 534533377.8437502 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549790618.171875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 544805768.9531251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 538727359.28125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 542160706.4062501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 546195261.953125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 503216986.375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 472103553.7343748 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 470883132.8906248 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 470496039.68750006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 470916741.9375002 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 470628696.6562498 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 468197583.3593752 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 463770327.15624994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 462996663.31249994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 463863467.70312494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 464242308.67187494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 464704361.546875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 465078107.2031248 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 466943812.5 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 468147990.89062494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 468590961.39062494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 467306235.078125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 466430622.40625024 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 466402109.8906248 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 465078910.04687476 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 462150750.76562506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 461069095.6874998 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 461255431.3437498 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 461958429.7343748 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 462290523.8125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 462349098.5468752 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 462379933.32812476 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 463967494.62499994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 465032380.6562502 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 464351012.76562476 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 463715054.4218752 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 464428891.39062476 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 464399607.6093748 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 398874604.96875006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 539673170.3124998 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 641376585.5937501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 644148353.265625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 641689840.6093751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 631773271.7656251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 624034700.0937499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 623737709.3125001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 631508748.6250001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 621427477.5625002 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 579890403.2812501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 556531047.0156251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548415650.7343749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548607029.6406251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548452835.0468749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 546803803.03125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547422004.8593749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548112483.46875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548763022.6718749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549325648.7343749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549912395.8749999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549859262.5312501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 551423873.4531251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552041882.125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 553023402.5781249 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 551868567.46875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550616734.9843749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550437630.46875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548479275.3281249 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 546783387.4843751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547015123.4843751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547535674.6250001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548072625.40625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548295635.6406249 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549108431.1249999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549064054.03125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550029136.21875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550419760.2812499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549393358.8437501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548241734.2656251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549051344.4062502 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550085202.4062499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 473341850.59375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 543348100.2968749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 642844750.8749999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 645960175.0 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 641339048.7968754 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 627755986.4531252 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 620932521.7031246 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 624048052.3749999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 627614442.5000001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 633422895.953125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 624535267.7656246 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 611083410.921875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 565248900.4375002 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548465532.8906251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548491749.2343751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 556425439.8593751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549513972.0937499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549719122.7343749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 551429220.4843751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 554661999.2499999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 556013009.6250001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550697866.921875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 553749571.6562499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 553609009.8750001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 551392915.4062501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550508696.1562499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550533180.59375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550223089.7812499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548578803.2968749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547139902.828125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547125612.015625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547243527.59375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548041659.7968751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 547951583.9374998 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548087095.2812501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549340668.6718751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550290613.8593748 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550865800.1406251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550220220.9687499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548749353.5468751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 548692538.9062502 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549038885.3750002 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 473635611.76562494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 542902101.7812499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 643142592.1249999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 642969246.0312499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 636005009.9999999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 628106414.96875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 636473489.9218752 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 633904012.5468749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 618328434.890625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 633868196.390625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 615682496.203125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 609512137.6250001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 588264040.0312501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 570994832.328125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 568188965.9531252 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 584982216.9843749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 568255706.0624998 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549529686.3906251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 549855263.109375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552076982.0000001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552723283.1249999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550124395.265625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552065657.2343749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552743508.3124999 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 553093025.71875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 552868472.828125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 551061442.6093751 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 550991333.3125002 and 0.0. Either the reference or moving image may be empty.
# ...
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 471452980.8593747 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 235285596.6093749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275313875.125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275639553.953125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276078793.53125006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276674873.90624994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276326827.78125006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276996165.17187494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277579920.40625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278041215.43750006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278139497.25000006 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 279205031.99999994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277893393.26562494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277888010.921875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277075186.5156249 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275876415.71874994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275336770.26562506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275234320.57812494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275328672.1875001 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 275669565.234375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276814698.70312494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277060207.70312506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277750780.9687499 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278496282.1875 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278741606.45312506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278365289.54687506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 278542103.17187506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277953420.06249994 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277243893.70312506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 274643475.67187494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 274772918.76562506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 284202183.70312494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 306063122.4843749 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 328310956.125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 339978050.14062494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 350043678.859375 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 328173378.9687501 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 277418970.42187506 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276766694.8281251 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276307831.28125 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276876305.625 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 276406102.57812494 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:35: UserWarning: Could not determine RMS error between images with the normalized average intensities 237738839.06249997 and 0.0. Either the reference or moving image may be empty.
#   shift,_,_ = phase_cross_correlation(im1_t_f, im2_t_f)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 img_de,z_de,ncc_list,vec_field_smooth_list = learn_and_apply_deformable(im1_happy,exvivo_image,vec_ds=2)
#       2 # img_de, z_de, ncc_list, vec_field_smooth_list = learn_and_apply_deformable(im1_wahba, exvivo_image, vec_ds)
#
# File /scratch/jl10897/multimodal_image_registration/functions/iterive_non_rigid.py:53, in learn_and_apply_deformable(im1_happy, im2, vec_ds, patch_sizes, patch_boarder, deform_kernel)
#      51 vec_field_smooth = vec_field.copy()
#      52 for coord in range(3):
# ---> 53     vec_field_smooth[:,:,:,coord] = ndi.gaussian_filter(vec_field[:,:,:,coord], ksz)
#      54 vec_field_smooth_list.append(vec_field_smooth)
#      56 shape = out.shape
#
# File /scratch/jl10897/miniconda3/envs/Auto_R/lib/python3.10/site-packages/scipy/ndimage/_filters.py:385, in gaussian_filter(input, sigma, order, output, mode, cval, truncate, radius, axes)
#     383 if len(axes) > 0:
#     384     for axis, sigma, order, mode, radius in axes:
# --> 385         gaussian_filter1d(input, sigma, axis, order, output,
#     386                           mode, cval, truncate, radius=radius)
#     387         input = output
#     388 else:
#
# File /scratch/jl10897/miniconda3/envs/Auto_R/lib/python3.10/site-packages/scipy/ndimage/_filters.py:283, in gaussian_filter1d(input, sigma, axis, order, output, mode, cval, truncate, radius)
#     281 # Since we are calling correlate, not convolve, revert the kernel
#     282 weights = _gaussian_kernel1d(sigma, order, lw)[::-1]
# --> 283 return correlate1d(input, weights, axis, output, mode, cval, 0)
#
# File /scratch/jl10897/miniconda3/envs/Auto_R/lib/python3.10/site-packages/scipy/ndimage/_filters.py:140, in correlate1d(input, weights, axis, output, mode, cval, origin)
#     136     raise ValueError('Invalid origin; origin must satisfy '
#     137                      '-(len(weights) // 2) <= origin <= '
#     138                      '(len(weights)-1) // 2')
#     139 mode = _ni_support._extend_mode_to_code(mode)
# --> 140 _nd_image.correlate1d(input, weights, axis, output, mode, cval,
#     141                       origin)
#     142 return output
#
# KeyboardInterrupt:

# %%
print("im1_wahba range:", np.min(im1_wahba), np.max(im1_wahba))
plt.imshow(np.max(im1_wahba, axis=0))  # 查看投影图像
plt.show()
# Out:
# im1_wahba range: -201.0911 69398.99

# %%
scl_1 = 0.1
scl_2 = 0.2
plt.figure(figsize=(23,11))
plt.subplot(1,3,1)
plt.imshow(gray2RGB(exvivo_image, col='r', scl=scl_1))
plt.subplot(1,3,2) 
plt.imshow(gray2RGB(exvivo_image, col='r', scl=scl_1) + 
         gray2RGB(img_de, col='g', scl=scl_2))
plt.yticks([])
plt.subplot(1,3,3)
plt.imshow(gray2RGB(invivo_image, col='g', scl=scl_2))
plt.yticks([])
plt.tight_layout()

# %%
# 直接计算形变后图像的匹配
cc_invivo, cc_exvivo, closest_pair, invivo_cent_new = count_cell_matching(img_de, exvivo_image)
